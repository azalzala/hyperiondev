# %% [markdown]
# # Machine Learning
# ## Compulsory task

# %% [markdown]
# 1. For each of the following examples describe at least one possible input and
# output. Justify your answers:
# * 1.1 A self-driving car
# * 1.2 Netflix recommendation system
# * 1.3 Signature recognition
# * 1.4 Medical diagnosis

# %% [markdown]
# 1. Answer here
#
# |      | Input(s)    | Output     |
# | ---- | ----------- | ---------  |
# | 1.1  | proximity to next vehicle, coordinates |   speed of vehicle, angle of wheel tilt |
# | 1.2  | users watch history | top movie/series picks for user |
# | 1.3  | a user's signature in image format| a degree of similarity between two signatures |
# | 1.4  | a patient's symptoms, medical history, age | likelihood of disease (s) and selection of top match |

# %% [markdown]
# 2. For each of the following case studies, determine whether it is appropriate to utilise regression or classification machine learning algorithms. Justify your answers:
# * 2.1 Classifying emails as promotion or social based on their content and metadata.
# * 2.2 Forecasting the stock price of a company based on historical data and market trends.
# * 2.3 Sorting images of animals into different species based on their visual features.
# * 2.4 Predicting the likelihood of a patient having a particular disease based on medical history and diagnostic test results.

# %% [markdown]
# 2. Answer here
# * 2.1) Classification ML algorithms will use the parameters content and metadata to produce decision rules that categorise each email with a probability of being a promotion or social email. Classification algorithms are better with qualitative data.
# * 2.2) Regression ML agorithm will be more appropriate to predict a continuous quantitative value like a stock price.
# * 2.3) Images can be classified as part of a species based on their visual features using a classification ML algorithm.
# * 2.4) The likelihood of a patient having a particular disease would be better targeted as a classification problem because the inputs might not have equal weight on the output,and the true relationship between predictors and response won't be represented properly using a linear model.

# %% [markdown]
# 3. For each of the following real-world problems, determine whether it is appropriate to utilise a supervised or unsupervised machine learning algorithm. Justify your answers:
# * 3.1 Detecting anomalies in a manufacturing process using sensor data without prior knowledge of specific anomaly patterns.
# * 3.2 Predicting customer lifetime value based on historical transaction data and customer demographics.
# * 3.3 Segmenting customer demographics based on their purchase history, browsing behaviour, and preferences.
# * 3.4 Analysing social media posts to categorise them into different themes.

# %% [markdown]
# 3. Answer here
# * 3.1)  This is an inference problem of which values are abnormal compared to normal data values. Without prior knowledge of specific anomaly patterns, sensor data can be continuously fed into the algorithm without labels to determine important patterns. These patterns will automatically detect anomalies. Therefore, a unsupervised ML algorithm would be better.
# * 3.2 A supervised algorithm that trains on existing examples of customer behavioural patterns is recommended versus a system that learns from itself, because the algorithm uses labelled data which will produce a rule that can calculate an estimate of customer lifetime value.
# * 3.3 Segmenting customer demographics is a prediction problem that would do better with a supervised learning algorithm. This is because existing labelled explanatory variables such as purchase history, browsing behaviour and preferences can be used to decide on optimal decision rules.
# * 3.4 To categorise social media posts into different themes, an unsupervised learning algorithm would do better because the lack of interpretability of features differing between millions of images can be differentiated continuously based on multiple parameters rather than a set of fixed labels.

# %% [markdown]
# 4.
# For each of the following real-world problems, determine whether it is appropriate to utilise semi-supervised machine learning algorithms. Justify your answers:
# * 4.1 Predicting fraudulent financial transactions using a dataset where most transactions are labelled as fraudulent or legitimate.
# * 4.2 Analysing customer satisfaction surveys where only a small portion of the data is labelled with satisfaction ratings.
# * 4.3 Identifying spam emails in a dataset where the majority of emails are labelled.
# * 4.4 Predicting the probability of default for credit card applicants based on their complete financial and credit-related information.

# %% [markdown]
# 4. Answer here
# * 4.1 No. A supervised algorithm would be sufficient in prediction problems with labelled features.
# * 4.2 Yes, it would be appropriate. Considering only some features are labelled with satisfaction ratings, there have to be other features that can help with inferring customer satisfaction. The semi-supervised ML algorithm ensures interpretability from existing data whilst also adding the flexibility from the unsupervised ML algorithm.
# * 4.3 Yes, as it is unknown which labels are associated with being spam, and thereofore further features and underlying patterns would be helpful that can be found using unsupervised ML algorithms.
# * 4.4 With complete financial and credit-related information, the number of parameters and inter-relationships between these and the output variable only needs a supervised learning algorithm. The available data with known outcomes can be used to train the algorithm.
